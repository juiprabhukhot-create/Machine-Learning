# %% [markdown]
# # **ASSIGNMENT 5 :- Naive Bayesian**

# %% [markdown]
# # **AIM:**
# Write a program to implement the naive Bayesian classifier for a sample
# training data set stored as a .CSV file. Compute the accuracy of the classifier, I
# considering few test data sets.

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.datasets import load_iris
print('Libraries imported')

# %% [markdown]
# Create Dataset

# %%
data = {
    'Income':[25000,30000,40000,50000,60000,70000,80000,90000,100000,120000],
    'Age':[22,25,28,32,35,40,45,50,55,60],
    'Credit_Score':[600,650,700,720,750,780,800,820,850,880],
    'Loan_Status':['Rejected','Rejected','Approved','Approved','Approved','Approved','Approved','Approved','Approved','Approved']
}

df = pd.DataFrame(data)
df.to_csv('loan_data.csv', index=False)
df.head()
# Out:
#    Income  Age  Credit_Score Loan_Status
# 0   25000   22           600    Rejected
# 1   30000   25           650    Rejected
# 2   40000   28           700    Approved
# 3   50000   32           720    Approved
# 4   60000   35           750    Approved

# %% [markdown]
# Load Dataset

# %%
data = pd.read_csv('loan_data.csv')

# %% [markdown]
# Explore Dataset

# %%
print('Shape:', data.shape)
print('\nColumns:', data.columns.tolist())
print('\nClass Distribution:')
print(data['Loan_Status'].value_counts())
data.describe()
# Out:
# Shape: (10, 4)
#
# Columns: ['Income', 'Age', 'Credit_Score', 'Loan_Status']
#
# Class Distribution:
# Loan_Status
# Approved    8
# Rejected    2
# Name: count, dtype: int64
#               Income        Age  Credit_Score
# count      10.000000  10.000000     10.000000
# mean    66500.000000  39.200000    755.000000
# std     31273.879765  13.019643     88.725544
# min     25000.000000  22.000000    600.000000
# 25%     42500.000000  29.000000    705.000000
# 50%     65000.000000  37.500000    765.000000
# 75%     87500.000000  48.750000    815.000000
# max    120000.000000  60.000000    880.000000

# %% [markdown]
# Seaprate Features

# %%
X = data.drop('Loan_Status', axis=1)
y = data['Loan_Status']
X.head()
# Out:
#    Income  Age  Credit_Score
# 0   25000   22           600
# 1   30000   25           650
# 2   40000   28           700
# 3   50000   32           720
# 4   60000   35           750

# %% [markdown]
# Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
print('Training size:', X_train.shape)
print('Testing size:', X_test.shape)
# Out:
# Training size: (7, 3)
# Testing size: (3, 3)

# %% [markdown]
# Build the Model

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
print('Model trained')
# Out:
# Model trained

# %% [markdown]
# Predict Test Data

# %%
y_pred = nb.predict(X_test)
list(y_pred)[:10]
# Out:
# [np.str_('Approved'), np.str_('Approved'), np.str_('Approved')]

# %% [markdown]
# Compare Actual vs Predicted (Correct / Wrong)

# %%
results = pd.DataFrame({'Actual': y_test.values, 'Predicted': y_pred})
results['Status'] = results.apply(lambda r: 'Correct' if r.Actual == r.Predicted else 'Wrong', axis=1)
results.head(20)
# Out:
#      Actual Predicted   Status
# 0  Approved  Approved  Correct
# 1  Rejected  Approved    Wrong
# 2  Approved  Approved  Correct

# %% [markdown]
# Compute Accuracy & Evaluation Metrics

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print('Accuracy:', accuracy_score(y_test, y_pred))
print('\nConfusion Matrix:\n', confusion_matrix(y_test, y_pred))
print('\nClassification Report:\n', classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6666666666666666
#
# Confusion Matrix:
#  [[2 0]
#  [1 0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     Approved       0.67      1.00      0.80         2
#     Rejected       0.00      0.00      0.00         1
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# # **Conclusion:**
# In this practical, a Naive Bayes classifier was implemented using a CSV dataset to perform classification. The dataset was split into training and testing sets, and the model was trained using the GaussianNB algorithm. The results showed good accuracy, indicating that the model can effectively predict outcomes based on input features.
#
# Naive Bayes works on the principle of probability and Bayes’ theorem, assuming that features are independent of each other. Despite this simple assumption, it performs well in many real-world scenarios.
